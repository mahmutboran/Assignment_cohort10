# %%
isim = "Boran"
while True:
  name = input("Lütfen kullanıcı adınızı giriniz: ").title()
  print("Çıkmak için 'q'tuşuna basınız!") 
  if name=="q":
    print("Sistemden çıkılıyor")
    break
  elif name==isim:
    print(f"Hello, {name}! The password is : W@12")
    break
  elif name!=isim:
    print(f"Hello, {name}! See you later.")
# Out:
# Lütfen kullanıcı adınızı giriniz: ali
# Çıkmak için 'q'tuşuna basınız!
# Hello, Ali! See you later.
# Lütfen kullanıcı adınızı giriniz: boran
# Çıkmak için 'q'tuşuna basınız!
# Hello, Boran! The password is : W@12
